# %% [markdown]
# # 1. File Handling

# %%
# Python has several functions for creating, reading, updating, and deleting files.
# open() is the key function to handle files - it has four modes
# "r" - read, "a" - append, "w" - write, "x" - create
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")

# f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt", "rt") - this is same as the above command r - read and t - text

# %% [markdown]
# # 2. Reading File

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.read()) # reads the file content
# Out:
# yay! I have written content into a file

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.read(5)) # to read only a part of the file - first 5 characters
# Out:
# yay!

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.readline()) # reads the first line of the file
# Out:
# yay! I have written content into a file

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.readline())
print(f.readline()) # calling readline() function twice, reads two lines of the file
# Out:
# yay! I have written content into a file

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
for x in f:
    print(x) # file contents can be looped through - line by line
# Out:
# yay! I have written content into a file

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.readline())
f.close()
# Out:
# yay! I have written content into a file

# %% [markdown]
# # 3. Write/Create Files

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt", "a")
f.write("Let's write one more line into the file")
f.close()

f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt", "r")
print(f.read())
# Out:
# yay! I have written content into a fileLet's write one more line into the file

# %%
f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt", "w")
f.write("yay! I have written content into a file")
f.close()

f = open("C:/Users/chand/OneDrive/Desktop/Visali/test.txt")
print(f.read())
# Out:
# yay! I have written content into a file

# %%
file = open("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt", "x")

# %%
file = open("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt", "w")
file.write("Hello! This is Viva")
file.close()

f = open("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt")
print(f.read())
f.close()
# Out:
# Hello! This is Viva

# %% [markdown]
# # 4. Delete Files

# %%
import os # to delete a file, OS module is needed
os.remove("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt")
# error occurs if the file doesn't exist

# %%
import os
if os.path.exists("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt"):
    os.remove("C:/Users/chand/OneDrive/Desktop/Visali/new_test.txt")
else:
    print("There is no such file!")
# Out:
# There is no such file!

# %%
import os
os.rmdir("C:/Users/chand/OneDrive/Desktop/Visali/test_folder")
# to remove the folder
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 import os
# ----> 2 os.rmdir("C:/Users/chand/OneDrive/Desktop/Visali/test_folder")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/chand/OneDrive/Desktop/Visali/test_folder'

# %% [markdown]
# # 5. Matplotlib

# %%
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# install matplotlib
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\chand\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chand\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\chand\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# import matplotlib
import matplotlib

# %%
# print version
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
# import matplotlib submodule pyplot using alias
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 6])
y = np.array([0, 250])
# plot() function is used to draw points (markers). By default, plot() draws the line connecting the points marked.
# parameter1 in the plot() function is an array of points on x-axis and parameter2 is for y-axis
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 8])
y = np.array([3, 10])

plt.plot(x, y)
plt.show()

# %%
# points can be plotter without line
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 8])
y = np.array([3, 10])

plt.plot(x, y, "o")
plt.show()

# %%
# multiple points
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])

plt.plot(x, y)
plt.show()

# %%
# default x-axis
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10, 5, 7])
# when x-axis values are not specified, those will be considered to be 0, 1, 2, 3,... etc based on the length of the y-axis array

plt.plot(y)
plt.show()

# %%
# markers
# keyword "marker" can be used within plot() function to specify the marker type
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y, marker = "o")
# if the marker keyword is not specified, it will be considered as points plotting style and connecting lines won't get plotted
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y, marker = "*")
# different types of markers can be used
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:r') 
# here, 'o:r' represent the marker|line|color combincation - this is called format strings
plt.show()

# %%
# line values are "-" for solid line, ":" for dotted line, "--" for dashed line, "-." for dashed/dotted line
# if the line value in the fmt parameter is left empty, no line will be plotted
# color values are - "r" for red, "g" for green, "b" for blue, "c" for cyan, "m" fo magenta, "y" for yellow, "b" for black, and "w" for white
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o-.m') 
plt.show()

# %%
# a keyword argument markersize or it's short form "ms" can be used to determind markersize
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:r', ms = 20) 
plt.show()

# %%
# a keyword argument markeredgecolor or mec can be used to specify the border color for the marker
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:m', ms = 20, mec = "r") 
plt.show()

# %%
# markerfacecolor or mfc can be used for face of the marker
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:r', ms = 20, mec = "b", mfc = "c") 
plt.show()

# %%
# hexadecimal color values also can be used
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:r', ms = 20, mec = "#4CAF50", mfc = "#4CAF50") 
plt.show()

# %%
# there are 140 color names which are supported witnin these statements
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'o:c', ms = 20, mec = "hotpink", mfc = "blue") 
plt.show()

# %%
# linestyle keyword argument or it's shortform ls can be used to specify the linestyle we are plotting
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, ls = "dotted") 
plt.show()

# %%
# keyword argument "color" or it's shortform "c" can be used to specify the line color
# all hexadecimal color values or supported color names can be used 
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, linestyle = "dashdot", color = "r") 
plt.show()

# %%
# keyword argument "linewidth" or it's shortform "lw" can be used to specify the line width
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, linestyle = "dashed", color = "c", lw = "10") 
plt.show()

# %%
# multiple plots
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1, 'o-.c', lw = '5')
plt.plot(y2, '*:m', lw = '5')

# %%
# draw two lines with different x and y values
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %%
# xlabel() and ylabel() are used for labelling x- and y- axes
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# title() is used to define the title pf the plot
import matplotlib.pyplot as plt
import numpy as np

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Colorie Burnage")
plt.title("Sports Watch Data")
plt.show()

# %%
# fontdict() parameter can be used to define fonts for each of these labels and title
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
# loc parameter can be used within title() to define the position of the title
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = "left")
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
# grid lines could also be added
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid()
plt.show()

# %%
# grid lines could be added only to one axis based on requirement
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
# line properties for the grid lines
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis = 'y', color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
# subplot() function
# subplot(1, 2, 1) - represents this subplot has 1 row 2 columns and first subplot

import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1) # 2 rows, 1 column, and first subplot
plt.plot(x, y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2) # 2 rows, 1 column, and second subplot
plt.plot(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
# suptitle() - a title for entire figure
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("My Shop")
plt.show()

# %%
# scatter plot - scatter() function is used to plot scatter plot

import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# multiple scatter plots can be plotted
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = "hotpink")
# color keyword is used to define the color of dots and color could be 
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = "#88c999")

plt.show()

# %%
# each dot of the scatter plot can be set with a specific color
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
# this has to be "colors". Shortform "c" cannnot be used

plt.scatter(x, y, c=colors)

plt.show()

# %%
# colormap - matplotlib module has a number of available colormaps
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
# cmap is the keyword argument to be used for the colormaps. virindis is one of the colormaps available in matplotlib
plt.show()

# %%
# colormap can be included in the drawing by including the plt.colorbar() statement
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c = colors, cmap = "viridis")
plt.colorbar()
plt.show()

# %%
# sizes of the dots can be customized using "s" argument
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, c = colors, cmap = "viridis", s = sizes)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s = sizes, c = colors, cmap = "viridis", alpha = 0.5)
# "alpha" argument is used to help adjust the transperancy of the dots
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))

colors = np.random.randint(100, size = (100))
sizes = 10 * np.random.randint(100, size = (100))

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.5, cmap = 'nipy_spectral')
plt.colorbar()
plt.show()

# %%
# bar() is for barcharts
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %%
# barh() is helpful for horizontal bar charts
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
# similar to scatter or line plots, color of the bars can be defined using hexacolors or color names
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
# bars width can be altered using keyword argument width
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.5)
plt.show()

# %%
# for horizontal bars, it is height instead of width
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.4)
plt.show()

# %%
# histograms - graph showing the frequency distributions
import numpy as np

x = np.random.normal(170, 10, 250)
# normal distribution with mean 170 and s.d. 10 of 250 values
print(x)
# Out:
# [166.51155797 168.05316273 168.24252076 170.9001952  154.05866064
#  171.84259968 169.09939512 175.97001697 183.06438357 153.79119795
#  164.79033597 166.3601738  162.9895661  169.65853707 164.81674917
#  166.26778774 168.6549619  179.80239932 173.73685035 159.35484322
#  183.8431431  174.90632751 187.53934742 174.77951164 183.79636612
#  180.87050133 182.057888   173.31881452 163.75796084 183.71629209
#  177.19609429 170.76651951 167.45154753 183.9472651  163.81261838
#  173.28977898 155.99886292 177.51297109 164.23972174 173.83496238
#  166.02059612 156.02013961 172.93871617 183.11003031 166.87133909
#  165.25429733 165.71285059 173.05670419 179.82754301 178.18837236
#  178.13955056 164.38141323 171.83312138 183.25184535 163.591089
#  176.05787555 183.66226989 176.25397365 174.73909351 162.85843106
